# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("../dataset/vgsales.csv")

# %%
data.shape
# Out:
# (16598, 11)

# %%
data.isnull().sum() #checking for total null values
# Out:
# Rank              0
# Name              0
# Platform          0
# Year            271
# Genre             0
# Publisher        58
# NA_Sales          0
# EU_Sales          0
# JP_Sales          0
# Other_Sales       0
# Global_Sales      0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16598 entries, 0 to 16597
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16598 non-null  int64
#  1   Name          16598 non-null  object
#  2   Platform      16598 non-null  object
#  3   Year          16327 non-null  float64
#  4   Genre         16598 non-null  object
#  5   Publisher     16540 non-null  object
#  6   NA_Sales      16598 non-null  float64
#  7   EU_Sales      16598 non-null  float64
#  8   JP_Sales      16598 non-null  float64
#  9   Other_Sales   16598 non-null  float64
#  10  Global_Sales  16598 non-null  float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.4+ MB

# %% [markdown]
# Their fields and data types are:
# - Rank - Ranking of overall sales, integer
# - Name - The games name
# - Platform - Platform of the games release (i.e. PC,PS4, etc.), object
# - Year - Year of the game's release, float
# - Genre - Genre of the game ,object
# - Publisher - Publisher of the game, object
# - NA_Sales - Sales in North America (in millions), float
# - EU_Sales - Sales in Europe (in millions), float
# - JP_Sales - Sales in Japan (in millions), float
# - Other_Sales - Sales in the rest of the world (in millions), float
# - Global_Sales - Total worldwide sales, float

# %%
print(data.describe)
data.describe()
# Out:
# <bound method NDFrame.describe of         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
# ...

# %%
data
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %% [markdown]
# ## Exploration Data Analysis

# %%
data['Genre'].value_counts()
# Out:
# Genre
# Action          3316
# Sports          2346
# Misc            1739
# Role-Playing    1488
# Shooter         1310
# Adventure       1286
# Racing          1249
# Platform         886
# Simulation       867
# Fighting         848
# Strategy         681
# Puzzle           582
# Name: count, dtype: int64

# %%
plt.figure(figsize=(16,9))
plt.title('MOST SELLING GAMES BY GENRE')
sns.countplot(data=data, x = 'Genre', order = data['Genre'].value_counts().index)
# Out:
# <Axes: title={'center': 'MOST SELLING GAMES BY GENRE'}, xlabel='Genre', ylabel='count'>

# %%
plt.figure(figsize=(16,9))
plt.title('WHAT PLATFORM DO THE GAMES GET PLAYED THE MOST')
sns.countplot(data=data, x = 'Platform', order = data['Platform'].value_counts().index)
# Out:
# <Axes: title={'center': 'WHAT PLATFORM DO THE GAMES GET PLAYED THE MOST'}, xlabel='Platform', ylabel='count'>

# %%
labels = data["Genre"].value_counts().index
sizes = data["Genre"].value_counts()
colors = ['#ff9999','#66b3ff','#99ff99','#ffcc99',"pink","yellow"]
plt.figure(figsize = (16,16))
plt.pie(sizes, labels=labels, rotatelabels=False, autopct='%1.1f%%',colors=colors,shadow=True, startangle=45)
plt.title('MOST SELLING GAMES BY GENRE',color = 'red',fontsize = 15)

plt.show()

# %%
plt.figure(figsize=(16,8))
sns.countplot(data=data,x='Year',)
# Out:
# <Axes: xlabel='Year', ylabel='count'>

# %%
np.round(data["NA_Sales"].sum(), 2)
# Out:
# 4392.95

# %%
NA = np.round(data["NA_Sales"].sum(), 2)

# %%
type(NA)
# Out:
# numpy.float64

# %%
pd.DataFrame(data.groupby("Genre")[["NA_Sales"]].sum().sort_values(by=['NA_Sales'],ascending=[False]).reset_index())
# Out:
#            Genre  NA_Sales
# 0         Action    877.83
# 1         Sports    683.35
# 2        Shooter    582.60
# 3       Platform    447.05
# 4           Misc    410.24
# 5         Racing    359.42
# 6   Role-Playing    327.28
# 7       Fighting    223.59
# 8     Simulation    183.31
# 9         Puzzle    123.78
# 10     Adventure    105.80
# 11      Strategy     68.70

# %%
# pd.DataFrame(data.groupby("Genre")[["NA_Sales"]].sum())

# %%
# data.groupby("Genre")[["NA_Sales"]].sum().reset_index()

# %%
# data.groupby("Genre")[["NA_Sales", "EU_Sales"]].aggregate("sum")

# %%
np.round(data["NA_Sales"].sum(), 2)
# Out:
# 4392.95

# %%
data["Global_Sales"].sum()
# Out:
# 8920.44

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Membaca dataset vgsales
df = pd.read_csv('../dataset/vgsales.csv')  # Ganti dengan path file vgsales.csv Anda

# Mengelompokkan penjualan berdasarkan wilayah
sales_columns = ['NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales']
total_sales_by_region = df[sales_columns].sum().sort_values(ascending=False)

# %%
total_sales_by_region
# Out:
# Global_Sales    8920.44
# NA_Sales        4392.95
# EU_Sales        2434.13
# JP_Sales        1291.02
# Other_Sales      797.75
# dtype: float64

# %%
# Membuat barplot
plt.figure(figsize=(12, 6))
sns.barplot(x=total_sales_by_region.index, y=total_sales_by_region.values)
plt.title('Total Penjualan Games berdasarkan Wilayah')
plt.xlabel('Wilayah')
plt.ylabel('Total Penjualan (dalam juta)')
plt.show()

# %%
import plotly.graph_objects as go
import pandas as pd

# Membuat DataFrame dari data vgsales (saya akan menggunakan contoh data yang diberikan sebelumnya)
df_vgsales = pd.DataFrame({
    "Game": ["Game1", "Game2", "Game3", "Game4", "Game5"],
    "NA_Sales": [10, 8, 12, 5, 15],
    "EU_Sales": [7, 5, 8, 3, 10],
    "JP_Sales": [2, 1, 4, 5, 6],
    "Other_Sales": [3, 2, 4, 1, 5],
    "Global_Sales": [22, 16, 28, 14, 36]
})

# Pilih variabel yang akan diplot
x_variable = "Game"  # Variabel kategorikal
y_variable = "Global_Sales"  # Variabel numerik

# %%
df_vgsales
# Out:
#     Game  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0  Game1        10         7         2            3            22
# 1  Game2         8         5         1            2            16
# 2  Game3        12         8         4            4            28
# 3  Game4         5         3         5            1            14
# 4  Game5        15        10         6            5            36

# %%
pd.DataFrame({
    "NA Sales" : df["NA_Sales"],
    "EU Sales" : df["EU_Sales"],
    "JP Sales" : df["JP_Sales"],
})
# Out:
#        NA Sales  EU Sales  JP Sales
# 0         41.49     29.02      3.77
# 1         29.08      3.58      6.81
# 2         15.85     12.88      3.79
# 3         15.75     11.01      3.28
# 4         11.27      8.89     10.22
# ...         ...       ...       ...
# 16593      0.01      0.00      0.00
# 16594      0.01      0.00      0.00
# 16595      0.00      0.00      0.00
# 16596      0.00      0.01      0.00
# 16597      0.01      0.00      0.00
#
# [16598 rows x 3 columns]

# %%
df = df[['NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales']].sum().sort_values(ascending=False).reset_index()

# %%
df.columns = ["Region", "Sales"]

# %%
df
# Out:
#          Region    Sales
# 0  Global_Sales  8920.44
# 1      NA_Sales  4392.95
# 2      EU_Sales  2434.13
# 3      JP_Sales  1291.02
# 4   Other_Sales   797.75

# %%
x = data.groupby(by=['Year'])['Global_Sales'].sum().reset_index()
